# %%
import numpy as np
import random

# %%
arrr = np.random.randint(1,100,size=(3,3))

# %%
arrr
# Out:
# array([[ 8, 40, 69],
#        [83, 28, 39],
#        [31, 19, 15]])

# %%
# an array with nan values
a = np.array([[1, 2, np.nan], [4, np.nan, 6], [7, 8, 9]])

# %%
np.isnan(a).sum()
# Out:
# 2

# %%
np.where(np.isnan(a))
# Out:
# (array([0, 1], dtype=int64), array([2, 1], dtype=int64))

# %%
np.array(arrr)[np.where(arrr > 50)]
# Out:
# array([69, 83])

# %%
arrr[np.where(arrr>20)]
# Out:
# array([40, 69, 83, 28, 39, 31])

# %%
arrr
# Out:
# array([[ 8, 40, 69],
#        [83, 28, 39],
#        [31, 19, 15]])

# %%
arrr[arrr>20]
# Out:
# array([40, 69, 83, 28, 39, 31])

# %%
np.where(arrr>20, 0, 1)
# Out:
# array([[1, 0, 0],
#        [0, 0, 0],
#        [0, 1, 1]])

# %%
np.where(arrr>20, 20, arrr)
# Out:
# array([[ 8, 20, 20],
#        [20, 20, 20],
#        [20, 19, 15]])

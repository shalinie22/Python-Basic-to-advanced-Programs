# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name": ["John", "Alice", "Bob"],
    "Age": [25, 30, 35]
})

# %%
df
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   35

# %%
df['Age'].map(lambda x: x+10)
# Out:
# 0    35
# 1    40
# 2    45
# Name: Age, dtype: int64

# %%
df
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   35

# %%
df['Age'].apply(lambda x: x+10)
# Out:
# 0    35
# 1    40
# 2    45
# Name: Age, dtype: int64

# %%
df
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   35

# %%
df.apply(max)
# Out:
# Name    John
# Age       35
# dtype: object
